# %%
import gym
import matplotlib.pyplot as plt
import sys
import numpy
import logging
sys.path.append('/home/maradona/neuron_poker/neuron_poker-master')
sys.path.append('/home/maradona/neuron_poker/neuron_poker-master/tools')
import numpy as np
import pandas as pd
import torch
import time
from collections import namedtuple, deque
from copy import deepcopy, copy
import random

# %%
#from gym_env.env import HoldemTable, Action, Stage, PlayerCycle, CommunityData, PlayerShell
from gym_env.env import HoldemTable, Action
from agents.agent_random import Player as RandomPlayer
from agents.agent_consider_equity import Player as EquityPlayer
from agents.agent_autoplay_random import Player as Random_autoplay_Player
from tools.helper import get_config
from tools.helper import init_logger
from tools.helper import flatten

# %%
#llença el logging, tant per pantalla com als log files

def logging_funct():

    print("Using default log file")
    logfile = 'default'
    model_name = 'test'
    screenloglevel = logging.INFO
    _ = get_config()
    init_logger(screenlevel=screenloglevel, filename=logfile)
    print(f"Screenloglevel: {screenloglevel}")
    log = logging.getLogger("")
    log.info("Initializing program")

# %%
#logging_funct()

# %%
def _create_env():
    """Create an environment"""
    env = HoldemTable()
    player = RandomPlayer(name='DQN_0')
    env.add_player(player)
    player = EquityPlayer(name='EQUITY_1', min_call_equity=0.2, min_bet_equity=0.7)
    env.add_player(player)
    return env

# %%
env = _create_env()

# %%
state0 = env.reset()   ##Cal inicialitzar-ho per carregar env.observation_space[0] a la xarxa neuronal

# %%
class experienceReplayBuffer:

    def __init__(self, memory_size=50000, burn_in=10000):
        self.memory_size = memory_size
        self.burn_in = burn_in
        self.buffer = namedtuple('Buffer', 
            field_names=['state', 'action', 'reward', 'done', 'next_state'])
        self.replay_memory = deque(maxlen=memory_size)

    def sample_batch(self, batch_size=32):
        samples = np.random.choice(len(self.replay_memory), batch_size, replace=False)
        # Use asterisk operator to unpack deque 
        batch = zip(*[self.replay_memory[i] for i in samples])
        return batch

    def append(self, state, action, reward, done, next_state):
        self.replay_memory.append(
            self.buffer(state, action, reward, done, next_state))

    def burn_in_capacity(self):
        return len(self.replay_memory) / self.burn_in

# %%
class NeuralNet(torch.nn.Module):  

    def __init__(self, env, learning_rate=1e-3):
        
        """
        Params
        ======
        n_inputs: tamaño del espacio de estadps
        n_outputs: tamaño del espacio de acciones
        actions: array de acciones posibles
        """
        
        ######################################
        ##Initialitzar paràmetres
        super(NeuralNet, self).__init__()
        self.n_inputs = env.observation_space[0]
        self.n_outputs = env.action_space.n
        self.actions = np.arange(env.action_space.n)
        self.learning_rate = learning_rate
        
       
    
    
        #######################################
        ##Neural network
        self.model = torch.nn.Sequential(
            torch.nn.Linear(self.n_inputs, 512, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(512, 256, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(128, self.n_outputs, bias=True))
        
        
        
        
        #######################################
        ##Inicialitzar optimitzador
        self.optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
          

            
            

    ### e-greedy method
    def get_action(self, state, epsilon=0.05):
        if np.random.random() < epsilon:
            action = random.choice(self.actions)
        else:
            qvals = self.get_qvals(state)  # acció del càlcul de Q per a aquesta acció
            no_legals = [x for x in np.arange(env.action_space.n) if x not in [x.value for x in env.legal_moves]]
            for i in no_legals:
                qvals[i] = float('-inf')   #posem a -inf tots els qvals que corresponen a moviments il-legals
            action= torch.max(qvals, dim=-1)[1].item()
        return action
    
    
    def get_qvals(self, state):
        if type(state) is tuple:
            state = np.array([np.ravel(s) for s in state])
        state_t = torch.FloatTensor(state)
        return self.model(state_t)

# %%
class DQNAgent:
    
    ###################################################
    ###### Declarar variables        ##################
    def __init__(self, reward_threshold, env, main_network, buffer, epsilon=0.1, eps_decay=0.99, batch_size=32): 
        self.env = env
        self.main_network = main_network
        self.target_network = deepcopy(main_network)
        self.buffer = buffer
        self.epsilon = epsilon
        self.eps_decay = eps_decay
        self.batch_size = batch_size
        self.nblock = 100 #bloc dels últims X episodis dels que es calcularà mitja de recompenses
        self.reward_threshold = reward_threshold
        self.initialize()
    
    
    ###############################################################
    ##### Inicialitzar variables extra que es necessitin###########
    def initialize(self):
        self.update_loss = []
        self.training_rewards = []
        self.mean_training_rewards = []
        self.sync_eps = []
        self.state0 = env.reset()
        self.total_reward = 0
        self.step_count = 0
        self.last_position = []
        self.epsilons = []
        self.training_loss = []
        self.ilegales = []
               
        
        
        
    #################################################################################
    ###### Prendre nova acció ###############################################
    def take_step(self, eps, mode='train'):
        if mode == 'explore':
            action = random.choice(self.main_network.actions)
        else:
            action = self.main_network.get_action(self.state0, eps)
            self.step_count += 1
            
        #prendre 'step' i obtenir nou estat i recompensa. Guardar experiència al buffer
        new_state, reward, done, _ = self.env.step(action)
        self.buffer.append(self.state0, action, reward, done, new_state)
        self.state0 = new_state.copy()
               
        if done:
            if mode == 'train':
                self.last_position.append(new_state[0])
            self.state0 = env.reset()
        return new_state, reward, done, _ 
        
        

    
        
    ##ENTRENAMENT
    def train(self, gamma=0.99, max_episodes=50000, 
              batch_size=32,
              dnn_update_frequency=4,
              dnn_sync_frequency=2000):
        self.gamma = gamma
        # Omplim el buffer amb N experiències aleatòries ()
        print("Filling replay buffer...")
        while self.buffer.burn_in_capacity() < 1:
            self.take_step(self.epsilon, mode='explore')
            
            
        episode = 0
        training = True
        print("Training...")
        while training:
            self.state0 = self.env.reset()
            self.total_reward = 0
            gamedone = False
            env.ilegal = 0
            while gamedone == False:
                #Agents autoplay de l'entorn
                if env._agent_is_autoplay(): #desencadena tot el joc autoplay
                    action = env.current_player.agent_obj.action(env.legal_moves, env.observation, env.info)
                    new_state, reward, gamedone, info = env.step(action)
                    if not gamedone:
                        reward = 0
                #Quan siguin més de 2 jugant he de finalitzaar partida si jo no jugo, o no pillar recompensa
                #Agent
                else:
                    new_state, reward, gamedone, info = self.take_step(self.epsilon, mode='train')
                
                self.total_reward += reward
                
                
                #################################################################################
                ##### Actualitzar la xarxa principal segons la freqüència establerta ############
                if self.step_count % dnn_update_frequency == 0:
                    self.update()
                
                
                
                    
                ########################################################################################
                ### Sincronitzar xarxa principal y xarxa objectiu segons la freqüència establerta#####

                if self.step_count % dnn_sync_frequency == 0:
                    self.target_network.load_state_dict(
                        self.main_network.state_dict())
                    self.sync_eps.append(episode)
                
                                
                if gamedone:  
                    episode += 1
                    self.training_rewards.append(self.total_reward)
                    self.training_loss.append(np.mean(self.update_loss))
                    self.update_loss = []   
                    self.ilegales.append(env.ilegal)
                
                    
                    #######################################################################################
                    ### Calcular la mitjana de recompensa dels últims X episodis, y almacenar#####
                    
                    mean_rewards = np.mean(self.training_rewards[-self.nblock:])
                    self.mean_training_rewards.append(mean_rewards)                   

                    print("\rEpisode {:d} Reward {:d} Mean Rewards {:.2f} Epsilon {} Illegal movements {:d}\t\t"
                          .format(episode, self.total_reward, mean_rewards, self.epsilon, env.ilegal), end="")
                    
                    #######################################################################################
                    ### Comprobar que encara queden episodis, i/o parar si s'ha arribat al límit

                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached.')
                        break
                        
                    
                    # Acaba el joc si la mitjana de recompenses ha arribat al llindar fixat per l'entorn     
                    if mean_rewards >= self.reward_threshold:
                        training = False
                        print('\nEnvironment solved in {} episodes!'.format(
                            episode))
                        break
                    
                    #################################################################################
                    ###### Actualitzar epsilon segons la velocitat de decaïment fixada########

                    self.epsilon = max(self.epsilon * self.eps_decay, 0.01)
                    self.epsilons.append(self.epsilon)
                                      
   

    ####################################          
    #####Càlcul de la pèrdua####
    def calculate_loss(self, batch):
        # Separem les variables de l'experiència i les convertim a tensors
        states, actions, rewards, dones, next_states = [i for i in batch] 
        rewards_vals = torch.FloatTensor(rewards)
        actions_vals = torch.LongTensor(np.array(actions)).reshape(-1,1)
        dones_t = torch.ByteTensor(dones)
        
        # Obtenim els valors de Q de la xarxa principal
        qvals = torch.gather(self.main_network.get_qvals(states), 1, actions_vals)
        # Obtenim els valors de Q de la xarxa objectiu. El paràmetre detach() 
        #evita que aquests valors actualitzin la xarxa objectiu
        qvals_next = torch.max(self.target_network.get_qvals(next_states),
                               dim=-1)[0].detach()
        qvals_next[dones_t] = 0 # 0 en estados terminales
        
        #################################################################################
        ### Calcular equació de Bellman
        expected_qvals = self.gamma * qvals_next + rewards_vals
        
        #################################################################################
        ### Càlcul de la pèrdua
        #loss = torch.nn.MSELoss()(qvals, expected_qvals.reshape(-1,1))
        loss = torch.nn.MSELoss()(qvals, expected_qvals)
        return loss

    
    def update(self):
        self.main_network.optimizer.zero_grad()  # eliminem qualsevol gradient passat
        batch = self.buffer.sample_batch(batch_size=self.batch_size) # seleccionem un conjunt del buffer
        loss = self.calculate_loss(batch) # calculem la pèrdua
        loss.backward() # fem la diferència per obtenir els gradients
        self.main_network.optimizer.step() # apliquem els gradients a la xarxa neuronal
        # Guardem els valors de pèrdua
        self.update_loss.append(loss.detach().numpy())

# %%
lr = 0.001
BATCH_SIZE = 32
MAX_EPISODES = 20000
BURN_IN = 1000
DNN_UPD = 3
DNN_SYNC = 1000
MEMORY_SIZE = 100000
EPSILON = 1           
EPSILON_DECAY = 0.9995  
GAMMA = 0.99   
REWARD_THRESHOLD = 1000000

# %%
buffer = experienceReplayBuffer(memory_size=MEMORY_SIZE, burn_in=BURN_IN)

# %%
dqn = NeuralNet(env, learning_rate=lr)

# %%
agentDQN = DQNAgent(REWARD_THRESHOLD, env, dqn, buffer, EPSILON, EPSILON_DECAY, BATCH_SIZE)

# %%
start = time.time()

# %%
agentDQN.train(gamma=GAMMA, max_episodes=MAX_EPISODES, 
               batch_size=BATCH_SIZE, dnn_update_frequency=DNN_UPD, dnn_sync_frequency=DNN_SYNC)
# Out:
# Filling replay buffer...
# Training...
# /home/maradona/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:168: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272126608/work/aten/src/ATen/native/TensorAdvancedIndexing.cpp:1273.)
# /home/maradona/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Episode 15 Reward -324 Mean Rewards 8.73 Epsilon 0.9930227045625007 Illegal movements 30
# /home/maradona/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/maradona/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Episode 20000 Reward 239 Mean Rewards 14.75 Epsilon 0.01 Illegal movements 1				movements 0
# Episode limit reached.

# %%
file = "/home/maradona/Desktop/data_science/TFM/3/DQNAgent_Trained_Model_Good_161.pth"
torch.save(agentDQN.main_network.state_dict(), file)

# %%
end = time.time()
print((end - start) / 3600)
# Out:
# 20.25572137170368

# %%
plt.figure(figsize=(8,4))
plt.plot(agentDQN.training_rewards, label='training rewards')
plt.plot(agentDQN.mean_training_rewards, label='mean training rewards')
#plt.axhline(env.spec.reward_threshold, color='r', label="reward threshold")
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend(loc="upper left")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(agentDQN.mean_training_rewards, label='mean training rewards')
#plt.axhline(env.spec.reward_threshold, color='r', label="reward threshold")
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend(loc="upper left")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(agentDQN.training_loss, label='Loss')
plt.xlabel('Episodes')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(agentDQN.epsilons, label='epsilon')
plt.xlabel('Episodes')
plt.ylabel('epsilon')
plt.legend(loc="upper left")
plt.show()

# %%
one = agentDQN.epsilons.index(0.01)
plt.figure(figsize=(8,4))
plt.plot(agentDQN.ilegales, label='Moviments Il-legals')
plt.xlabel('Episodes')
plt.ylabel('Moviments Il-legals')
plt.legend(loc="upper left")
plt.axvline(x = one, color = 'g') 
plt.show()

# %%
agentDQN.main_network.load_state_dict(torch.load
                                      ('/home/maradona/Desktop/data_science/TFM/3/DQNAgent_Trained_Model_Good_161.pth'))
# Out:
# <All keys matched successfully>

# %%
rewards = []
winner = []
stack = []
ilegales = []
rango = 500
for episode in range(rango):
    observation = env.reset()
    total_reward = 0
    t = 0
    env.ilegal = 0
    while True:
        action = agentDQN.main_network.get_action(observation)
        observation, reward, done, info = env.step(action)
        total_reward += reward
        t += 1
        if done:
            rewards.append(total_reward)
            ilegales.append(env.ilegal)
            winner.append(env.winner_ix)
            for i in range(len(env.players)):
                if env.players[i].name == 'DQN_0':
                    stack.append(env.players[i].stack)
            break
    print('Episode {}\tReward: {:.2f} \tFinished in {} timesteps\tIlegal movements {}\tStack {}\t Winner {}\n'
          .format(episode, total_reward, t+1, ilegales[episode], stack[episode], winner[episode]), end="")
print("\n\n % partides guanyades: ",winner.count(0)/rango)
print("\n\n mitja de recompenses: ",sum(rewards)/len(rewards))
print("\n\n mitja de $$$$$$$$$$$: ",sum(stack)/len(stack))
# Out:
# Episode 0	Reward: -242.00 	Finished in 57 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 1	Reward: 140.00 	Finished in 26 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 2	Reward: -293.00 	Finished in 51 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 3	Reward: -419.00 	Finished in 101 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 4	Reward: -202.00 	Finished in 6 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 5	Reward: 118.00 	Finished in 69 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 6	Reward: -138.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 7	Reward: -301.00 	Finished in 123 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 8	Reward: 169.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 9	Reward: -268.00 	Finished in 51 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 10	Reward: -226.00 	Finished in 144 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 11	Reward: 246.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 12	Reward: 124.00 	Finished in 62 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 13	Reward: -162.00 	Finished in 29 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 14	Reward: -226.00 	Finished in 75 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 15	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 16	Reward: 66.00 	Finished in 108 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 17	Reward: -227.00 	Finished in 41 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 18	Reward: -161.00 	Finished in 39 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 19	Reward: 32.00 	Finished in 82 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 20	Reward: -399.00 	Finished in 102 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 21	Reward: -237.00 	Finished in 164 timesteps	Ilegal movements 4	Stack 0	 Winner 1
# Episode 22	Reward: 102.00 	Finished in 38 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 23	Reward: 35.00 	Finished in 64 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 24	Reward: 63.00 	Finished in 59 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 25	Reward: -161.00 	Finished in 86 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 26	Reward: -306.00 	Finished in 75 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 27	Reward: -436.00 	Finished in 125 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 28	Reward: -396.00 	Finished in 100 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 29	Reward: -206.00 	Finished in 28 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 30	Reward: -55.00 	Finished in 110 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 31	Reward: -191.00 	Finished in 211 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 32	Reward: 102.00 	Finished in 10 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 33	Reward: -110.00 	Finished in 153 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 34	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 35	Reward: -305.00 	Finished in 80 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 36	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 37	Reward: 108.00 	Finished in 35 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 38	Reward: -215.00 	Finished in 74 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 39	Reward: -378.00 	Finished in 164 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 40	Reward: 165.00 	Finished in 37 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 41	Reward: 130.00 	Finished in 92 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 42	Reward: -606.00 	Finished in 228 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 43	Reward: -309.00 	Finished in 234 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 44	Reward: -427.00 	Finished in 138 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 45	Reward: 72.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 46	Reward: -456.00 	Finished in 148 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 47	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 48	Reward: 120.00 	Finished in 36 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 49	Reward: 170.00 	Finished in 16 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 50	Reward: 272.00 	Finished in 27 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 51	Reward: 114.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 52	Reward: 160.00 	Finished in 24 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 53	Reward: 162.00 	Finished in 20 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 54	Reward: -81.00 	Finished in 112 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 55	Reward: 105.00 	Finished in 24 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 56	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 57	Reward: -683.00 	Finished in 178 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 58	Reward: -268.00 	Finished in 96 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 59	Reward: 92.00 	Finished in 51 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 60	Reward: -265.00 	Finished in 259 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 61	Reward: 136.00 	Finished in 32 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 62	Reward: -446.00 	Finished in 137 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 63	Reward: 68.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 64	Reward: 93.00 	Finished in 51 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 65	Reward: -324.00 	Finished in 61 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 66	Reward: 128.00 	Finished in 38 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 67	Reward: -321.00 	Finished in 83 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 68	Reward: 48.00 	Finished in 99 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 69	Reward: 50.00 	Finished in 80 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 70	Reward: -136.00 	Finished in 139 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 71	Reward: -273.00 	Finished in 123 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 72	Reward: -348.00 	Finished in 83 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 73	Reward: -367.00 	Finished in 77 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 74	Reward: 108.00 	Finished in 35 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 75	Reward: -594.00 	Finished in 277 timesteps	Ilegal movements 7	Stack 0	 Winner 1
# Episode 76	Reward: -161.00 	Finished in 127 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 77	Reward: -2.00 	Finished in 109 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 78	Reward: -220.00 	Finished in 45 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 79	Reward: 46.00 	Finished in 55 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 80	Reward: -97.00 	Finished in 130 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 81	Reward: -218.00 	Finished in 79 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 82	Reward: 137.00 	Finished in 35 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 83	Reward: 188.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 84	Reward: 118.00 	Finished in 34 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 85	Reward: -212.00 	Finished in 142 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 86	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 87	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 88	Reward: 168.00 	Finished in 16 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 89	Reward: 61.00 	Finished in 57 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 90	Reward: -250.00 	Finished in 54 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 91	Reward: -222.00 	Finished in 39 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 92	Reward: -646.00 	Finished in 198 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 93	Reward: -147.00 	Finished in 99 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 94	Reward: 112.00 	Finished in 42 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 95	Reward: 7.00 	Finished in 80 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 96	Reward: -20.00 	Finished in 132 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 97	Reward: -194.00 	Finished in 71 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 98	Reward: -472.00 	Finished in 207 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 99	Reward: 124.00 	Finished in 35 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 100	Reward: 51.00 	Finished in 44 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 101	Reward: -27.00 	Finished in 108 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 102	Reward: -182.00 	Finished in 140 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 103	Reward: -604.00 	Finished in 231 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 104	Reward: 38.00 	Finished in 47 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 105	Reward: 64.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 106	Reward: -320.00 	Finished in 79 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 107	Reward: 97.00 	Finished in 22 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 108	Reward: -221.00 	Finished in 42 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 109	Reward: 194.00 	Finished in 34 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 110	Reward: -253.00 	Finished in 63 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 111	Reward: -326.00 	Finished in 142 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 112	Reward: 144.00 	Finished in 34 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 113	Reward: -221.00 	Finished in 63 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 114	Reward: 96.00 	Finished in 41 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 115	Reward: -140.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 116	Reward: 136.00 	Finished in 26 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 117	Reward: -415.00 	Finished in 133 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 118	Reward: -14.00 	Finished in 72 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 119	Reward: 82.00 	Finished in 75 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 120	Reward: -338.00 	Finished in 109 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 121	Reward: -368.00 	Finished in 127 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 122	Reward: 134.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 123	Reward: -214.00 	Finished in 64 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 124	Reward: -346.00 	Finished in 104 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 125	Reward: 12.00 	Finished in 97 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 126	Reward: -391.00 	Finished in 124 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 127	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 128	Reward: -392.00 	Finished in 107 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 129	Reward: 50.00 	Finished in 50 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 130	Reward: 144.00 	Finished in 20 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 131	Reward: 116.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 132	Reward: 184.00 	Finished in 41 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 133	Reward: -51.00 	Finished in 93 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 134	Reward: 80.00 	Finished in 204 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 135	Reward: 22.00 	Finished in 80 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 136	Reward: 64.00 	Finished in 97 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 137	Reward: 41.00 	Finished in 66 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 138	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 139	Reward: -154.00 	Finished in 52 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 140	Reward: -294.00 	Finished in 50 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 141	Reward: -56.00 	Finished in 111 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 142	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 143	Reward: 64.00 	Finished in 78 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 144	Reward: -328.00 	Finished in 64 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 145	Reward: 88.00 	Finished in 69 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 146	Reward: -403.00 	Finished in 86 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 147	Reward: -267.00 	Finished in 76 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 148	Reward: 158.00 	Finished in 30 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 149	Reward: 278.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 150	Reward: 72.00 	Finished in 59 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 151	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 152	Reward: -239.00 	Finished in 152 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 153	Reward: 127.00 	Finished in 41 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 154	Reward: -214.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 155	Reward: -219.00 	Finished in 57 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 156	Reward: 120.00 	Finished in 36 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 157	Reward: 158.00 	Finished in 44 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 158	Reward: 168.00 	Finished in 20 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 159	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 160	Reward: 58.00 	Finished in 63 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 161	Reward: 114.00 	Finished in 29 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 162	Reward: -316.00 	Finished in 89 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 163	Reward: -92.00 	Finished in 98 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 164	Reward: -272.00 	Finished in 100 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 165	Reward: -303.00 	Finished in 60 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 166	Reward: -38.00 	Finished in 161 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 167	Reward: 156.00 	Finished in 82 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 168	Reward: 207.00 	Finished in 61 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 169	Reward: 228.00 	Finished in 20 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 170	Reward: 130.00 	Finished in 37 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 171	Reward: 98.00 	Finished in 37 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 172	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 173	Reward: -319.00 	Finished in 80 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 174	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 175	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 176	Reward: 34.00 	Finished in 96 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 177	Reward: 108.00 	Finished in 71 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 178	Reward: -188.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 179	Reward: 130.00 	Finished in 57 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 180	Reward: 91.00 	Finished in 57 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 181	Reward: -400.00 	Finished in 60 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 182	Reward: -284.00 	Finished in 71 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 183	Reward: -338.00 	Finished in 185 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 184	Reward: -234.00 	Finished in 24 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 185	Reward: -142.00 	Finished in 159 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 186	Reward: 38.00 	Finished in 112 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 187	Reward: -72.00 	Finished in 130 timesteps	Ilegal movements 4	Stack 200	 Winner 0
# Episode 188	Reward: 19.00 	Finished in 72 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 189	Reward: 152.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 190	Reward: 159.00 	Finished in 25 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 191	Reward: 99.00 	Finished in 17 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 192	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 193	Reward: 73.00 	Finished in 278 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 194	Reward: -163.00 	Finished in 29 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 195	Reward: 114.00 	Finished in 39 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 196	Reward: -291.00 	Finished in 51 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 197	Reward: -160.00 	Finished in 78 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 198	Reward: 146.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 199	Reward: -489.00 	Finished in 118 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 200	Reward: -30.00 	Finished in 86 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 201	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 202	Reward: -424.00 	Finished in 123 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 203	Reward: -139.00 	Finished in 66 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 204	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 205	Reward: -94.00 	Finished in 109 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 206	Reward: -329.00 	Finished in 153 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 207	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 208	Reward: -88.00 	Finished in 120 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 209	Reward: 168.00 	Finished in 20 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 210	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 211	Reward: 79.00 	Finished in 39 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 212	Reward: -172.00 	Finished in 54 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 213	Reward: -201.00 	Finished in 81 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 214	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 215	Reward: 19.00 	Finished in 119 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 216	Reward: -297.00 	Finished in 40 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 217	Reward: -6.00 	Finished in 238 timesteps	Ilegal movements 4	Stack 200	 Winner 0
# Episode 218	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 219	Reward: 114.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 220	Reward: -287.00 	Finished in 91 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 221	Reward: -177.00 	Finished in 186 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 222	Reward: 119.00 	Finished in 63 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 223	Reward: -151.00 	Finished in 69 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 224	Reward: -13.00 	Finished in 96 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 225	Reward: -538.00 	Finished in 123 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 226	Reward: 116.00 	Finished in 65 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 227	Reward: -303.00 	Finished in 100 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 228	Reward: -24.00 	Finished in 87 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 229	Reward: -242.00 	Finished in 72 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 230	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 231	Reward: 128.00 	Finished in 48 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 232	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 233	Reward: 80.00 	Finished in 65 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 234	Reward: -49.00 	Finished in 123 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 235	Reward: -290.00 	Finished in 63 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 236	Reward: 86.00 	Finished in 58 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 237	Reward: -267.00 	Finished in 40 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 238	Reward: 158.00 	Finished in 26 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 239	Reward: -105.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 240	Reward: -22.00 	Finished in 164 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 241	Reward: -239.00 	Finished in 85 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 242	Reward: 106.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 243	Reward: -72.00 	Finished in 210 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 244	Reward: -62.00 	Finished in 119 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 245	Reward: 20.00 	Finished in 77 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 246	Reward: -198.00 	Finished in 30 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 247	Reward: 53.00 	Finished in 117 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 248	Reward: 167.00 	Finished in 21 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 249	Reward: -295.00 	Finished in 33 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 250	Reward: -292.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 251	Reward: 46.00 	Finished in 80 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 252	Reward: -171.00 	Finished in 133 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 253	Reward: 102.00 	Finished in 14 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 254	Reward: -151.00 	Finished in 44 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 255	Reward: -48.00 	Finished in 150 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 256	Reward: -208.00 	Finished in 9 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 257	Reward: -219.00 	Finished in 57 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 258	Reward: -237.00 	Finished in 68 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 259	Reward: -403.00 	Finished in 119 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 260	Reward: -351.00 	Finished in 74 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 261	Reward: -331.00 	Finished in 127 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 262	Reward: -301.00 	Finished in 38 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 263	Reward: 157.00 	Finished in 27 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 264	Reward: 124.00 	Finished in 39 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 265	Reward: -362.00 	Finished in 84 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 266	Reward: -182.00 	Finished in 34 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 267	Reward: 7.00 	Finished in 100 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 268	Reward: -148.00 	Finished in 54 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 269	Reward: 174.00 	Finished in 39 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 270	Reward: 68.00 	Finished in 49 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 271	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 272	Reward: -228.00 	Finished in 48 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 273	Reward: -484.00 	Finished in 314 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 274	Reward: -246.00 	Finished in 184 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 275	Reward: -574.00 	Finished in 150 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 276	Reward: -92.00 	Finished in 131 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 277	Reward: -304.00 	Finished in 151 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 278	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 279	Reward: -272.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 280	Reward: -371.00 	Finished in 98 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 281	Reward: 135.00 	Finished in 26 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 282	Reward: -219.00 	Finished in 67 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 283	Reward: 102.00 	Finished in 10 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 284	Reward: -9.00 	Finished in 108 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 285	Reward: -226.00 	Finished in 68 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 286	Reward: -50.00 	Finished in 157 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 287	Reward: 6.00 	Finished in 67 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 288	Reward: -263.00 	Finished in 179 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 289	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 290	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 291	Reward: -420.00 	Finished in 72 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 292	Reward: 76.00 	Finished in 109 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 293	Reward: 238.00 	Finished in 32 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 294	Reward: 100.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 295	Reward: -622.00 	Finished in 172 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 296	Reward: -16.00 	Finished in 134 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 297	Reward: -123.00 	Finished in 51 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 298	Reward: 48.00 	Finished in 65 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 299	Reward: 32.00 	Finished in 84 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 300	Reward: -202.00 	Finished in 8 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 301	Reward: -322.00 	Finished in 79 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 302	Reward: 122.00 	Finished in 63 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 303	Reward: -240.00 	Finished in 81 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 304	Reward: 161.00 	Finished in 22 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 305	Reward: -87.00 	Finished in 147 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 306	Reward: -309.00 	Finished in 122 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 307	Reward: -353.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 308	Reward: -349.00 	Finished in 185 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 309	Reward: -151.00 	Finished in 182 timesteps	Ilegal movements 3	Stack 200	 Winner 0
# Episode 310	Reward: -164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 311	Reward: -227.00 	Finished in 36 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 312	Reward: 134.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 313	Reward: 23.00 	Finished in 60 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 314	Reward: 59.00 	Finished in 46 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 315	Reward: -224.00 	Finished in 83 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 316	Reward: -274.00 	Finished in 49 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 317	Reward: -500.00 	Finished in 141 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 318	Reward: 295.00 	Finished in 35 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 319	Reward: 178.00 	Finished in 48 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 320	Reward: -334.00 	Finished in 57 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 321	Reward: 146.00 	Finished in 26 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 322	Reward: -255.00 	Finished in 109 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 323	Reward: -291.00 	Finished in 70 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 324	Reward: 106.00 	Finished in 38 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 325	Reward: -70.00 	Finished in 112 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 326	Reward: 160.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 327	Reward: -100.00 	Finished in 134 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 328	Reward: -364.00 	Finished in 73 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 329	Reward: 121.00 	Finished in 44 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 330	Reward: 113.00 	Finished in 40 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 331	Reward: -311.00 	Finished in 177 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 332	Reward: -427.00 	Finished in 143 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 333	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 334	Reward: 145.00 	Finished in 29 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 335	Reward: 169.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 336	Reward: 124.00 	Finished in 62 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 337	Reward: 40.00 	Finished in 88 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 338	Reward: -390.00 	Finished in 111 timesteps	Ilegal movements 4	Stack 0	 Winner 1
# Episode 339	Reward: 30.00 	Finished in 83 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 340	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 341	Reward: -345.00 	Finished in 89 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 342	Reward: 163.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 343	Reward: -123.00 	Finished in 142 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 344	Reward: 57.00 	Finished in 54 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 345	Reward: 50.00 	Finished in 58 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 346	Reward: -179.00 	Finished in 51 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 347	Reward: -407.00 	Finished in 98 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 348	Reward: -227.00 	Finished in 203 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 349	Reward: -290.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 350	Reward: 161.00 	Finished in 22 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 351	Reward: 44.00 	Finished in 38 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 352	Reward: -255.00 	Finished in 109 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 353	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 354	Reward: -223.00 	Finished in 46 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 355	Reward: -224.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 356	Reward: -305.00 	Finished in 61 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 357	Reward: 282.00 	Finished in 16 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 358	Reward: 48.00 	Finished in 140 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 359	Reward: 51.00 	Finished in 59 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 360	Reward: 169.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 361	Reward: 1.00 	Finished in 71 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 362	Reward: 102.00 	Finished in 14 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 363	Reward: -442.00 	Finished in 132 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 364	Reward: -59.00 	Finished in 90 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 365	Reward: -31.00 	Finished in 90 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 366	Reward: 114.00 	Finished in 41 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 367	Reward: -544.00 	Finished in 142 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 368	Reward: -214.00 	Finished in 58 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 369	Reward: -246.00 	Finished in 106 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 370	Reward: 158.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 371	Reward: 234.00 	Finished in 44 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 372	Reward: -106.00 	Finished in 76 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 373	Reward: 102.00 	Finished in 11 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 374	Reward: -53.00 	Finished in 113 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 375	Reward: -34.00 	Finished in 226 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 376	Reward: -211.00 	Finished in 53 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 377	Reward: -414.00 	Finished in 156 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 378	Reward: 9.00 	Finished in 108 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 379	Reward: -109.00 	Finished in 13 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 380	Reward: -282.00 	Finished in 60 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 381	Reward: -250.00 	Finished in 73 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 382	Reward: 156.00 	Finished in 30 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 383	Reward: -172.00 	Finished in 77 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 384	Reward: -258.00 	Finished in 101 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 385	Reward: -170.00 	Finished in 35 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 386	Reward: -468.00 	Finished in 120 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 387	Reward: 54.00 	Finished in 105 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 388	Reward: -79.00 	Finished in 149 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 389	Reward: 1.00 	Finished in 99 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 390	Reward: -239.00 	Finished in 70 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 391	Reward: 156.00 	Finished in 26 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 392	Reward: 102.00 	Finished in 23 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 393	Reward: 134.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 394	Reward: 146.00 	Finished in 66 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 395	Reward: -483.00 	Finished in 111 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 396	Reward: 0.00 	Finished in 113 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 397	Reward: -261.00 	Finished in 236 timesteps	Ilegal movements 5	Stack 200	 Winner 0
# Episode 398	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 399	Reward: 17.00 	Finished in 99 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 400	Reward: -1094.00 	Finished in 508 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 401	Reward: 124.00 	Finished in 68 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 402	Reward: -290.00 	Finished in 31 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 403	Reward: -28.00 	Finished in 91 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 404	Reward: 15.00 	Finished in 88 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 405	Reward: 101.00 	Finished in 41 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 406	Reward: -158.00 	Finished in 128 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 407	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 408	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 409	Reward: -34.00 	Finished in 144 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 410	Reward: -274.00 	Finished in 183 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 411	Reward: 28.00 	Finished in 130 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 412	Reward: -227.00 	Finished in 51 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 413	Reward: 162.00 	Finished in 14 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 414	Reward: 169.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 415	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 416	Reward: -658.00 	Finished in 238 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 417	Reward: -202.00 	Finished in 343 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 418	Reward: 110.00 	Finished in 107 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 419	Reward: -153.00 	Finished in 98 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 420	Reward: -152.00 	Finished in 73 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 421	Reward: -273.00 	Finished in 103 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 422	Reward: 35.00 	Finished in 49 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 423	Reward: 161.00 	Finished in 22 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 424	Reward: -450.00 	Finished in 166 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 425	Reward: -282.00 	Finished in 42 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 426	Reward: 104.00 	Finished in 49 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 427	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 428	Reward: 158.00 	Finished in 20 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 429	Reward: -294.00 	Finished in 55 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 430	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 431	Reward: -509.00 	Finished in 283 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 432	Reward: 163.00 	Finished in 19 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 433	Reward: 119.00 	Finished in 42 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 434	Reward: 158.00 	Finished in 27 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 435	Reward: 170.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 436	Reward: 72.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 437	Reward: 69.00 	Finished in 63 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 438	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 439	Reward: 78.00 	Finished in 67 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 440	Reward: -670.00 	Finished in 170 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 441	Reward: -375.00 	Finished in 104 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 442	Reward: -150.00 	Finished in 127 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 443	Reward: 48.00 	Finished in 88 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 444	Reward: -144.00 	Finished in 211 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 445	Reward: -291.00 	Finished in 68 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 446	Reward: 230.00 	Finished in 17 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 447	Reward: -152.00 	Finished in 108 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 448	Reward: -249.00 	Finished in 110 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 449	Reward: -424.00 	Finished in 102 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 450	Reward: -450.00 	Finished in 325 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 451	Reward: -333.00 	Finished in 85 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 452	Reward: 109.00 	Finished in 131 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 453	Reward: 68.00 	Finished in 71 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 454	Reward: -221.00 	Finished in 51 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 455	Reward: -427.00 	Finished in 98 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 456	Reward: 64.00 	Finished in 58 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 457	Reward: 93.00 	Finished in 73 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 458	Reward: -321.00 	Finished in 79 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 459	Reward: -116.00 	Finished in 191 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 460	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 461	Reward: 170.00 	Finished in 13 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 462	Reward: -260.00 	Finished in 79 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 463	Reward: -438.00 	Finished in 119 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 464	Reward: 88.00 	Finished in 40 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 465	Reward: 80.00 	Finished in 61 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 466	Reward: -206.00 	Finished in 6 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 467	Reward: 100.00 	Finished in 43 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 468	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 469	Reward: -303.00 	Finished in 75 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 470	Reward: -512.00 	Finished in 116 timesteps	Ilegal movements 2	Stack 0	 Winner 1
# Episode 471	Reward: 67.00 	Finished in 60 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 472	Reward: -522.00 	Finished in 124 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 473	Reward: 30.00 	Finished in 113 timesteps	Ilegal movements 2	Stack 200	 Winner 0
# Episode 474	Reward: -542.00 	Finished in 203 timesteps	Ilegal movements 5	Stack 0	 Winner 1
# Episode 475	Reward: -448.00 	Finished in 223 timesteps	Ilegal movements 6	Stack 0	 Winner 1
# Episode 476	Reward: -59.00 	Finished in 111 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 477	Reward: 168.00 	Finished in 36 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 478	Reward: -324.00 	Finished in 95 timesteps	Ilegal movements 3	Stack 0	 Winner 1
# Episode 479	Reward: 19.00 	Finished in 46 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 480	Reward: 110.00 	Finished in 47 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 481	Reward: -442.00 	Finished in 131 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 482	Reward: -93.00 	Finished in 97 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 483	Reward: -465.00 	Finished in 129 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 484	Reward: 97.00 	Finished in 60 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 485	Reward: 99.00 	Finished in 19 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 486	Reward: -221.00 	Finished in 81 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 487	Reward: 164.00 	Finished in 18 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 488	Reward: -153.00 	Finished in 84 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 489	Reward: -315.00 	Finished in 94 timesteps	Ilegal movements 4	Stack 0	 Winner 1
# Episode 490	Reward: -394.00 	Finished in 177 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 491	Reward: 61.00 	Finished in 78 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 492	Reward: -307.00 	Finished in 60 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 493	Reward: 69.00 	Finished in 52 timesteps	Ilegal movements 1	Stack 200	 Winner 0
# Episode 494	Reward: -554.00 	Finished in 154 timesteps	Ilegal movements 1	Stack 0	 Winner 1
# Episode 495	Reward: -256.00 	Finished in 50 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 496	Reward: 43.00 	Finished in 59 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 497	Reward: 162.00 	Finished in 21 timesteps	Ilegal movements 0	Stack 200	 Winner 0
# Episode 498	Reward: -291.00 	Finished in 65 timesteps	Ilegal movements 0	Stack 0	 Winner 1
# Episode 499	Reward: 134.00 	Finished in 36 timesteps	Ilegal movements 0	Stack 200	 Winner 0
#
#
#  % partides guanyades:  0.606
#
#
#  mitja de recompenses:  -82.828
#
#
#  mitja de $$$$$$$$$$$:  121.2
